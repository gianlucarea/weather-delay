# %% [markdown]
# # Import

# %%
import pandas as pd
import gtfs_kit as gk
import helper #homemade function file helper.py
import warnings
import numpy as np
from tqdm import tqdm

warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %% [markdown]
# # Main Dataset Creation

# %%
# Load Delays
delays_exp = pd.read_csv('../processed_files/delays_preprocessing_expanded.csv',index_col=[0])
# Load Weather
delays = pd.read_csv('../processed_files/delays_preprocessing_general_dataset.csv',index_col=[0])
#weather = pd.read_csv('prova.csv',index_col=[0])
# Out:
# /var/folders/zt/4qm_9p2d267_7b0p2r1hsg840000gn/T/ipykernel_34468/4175771529.py:4: DtypeWarning: Columns (15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   delays = pd.read_csv('../processed_files/delays_preprocessing_general_dataset.csv',index_col=[0])

# %%
delays = delays.reset_index(drop=True)
delays
# Out:
#       codice             punto_partenza  ritardo_partenza  \
# 0      19192          PIAZZA AL SERCHIO                 2
# 1      19194          PIAZZA AL SERCHIO                 1
# 2      18551              PISA CENTRALE                 7
# 3      19191          PIAZZA AL SERCHIO                 4
# 4      18552                      LUCCA                 2
# ...      ...                        ...               ...
# 71792  19183  CASTELNUOVO DI GARFAGNANA                 1
# 71793   6242                      LUCCA                 2
# 71794  18603              PISA CENTRALE                 1
# 71795  18605              PISA CENTRALE                 2
# 71796  18610                      LUCCA                 5
#
#                     punto_arrivo  ritardo_arrivo categoria         oaz  \
# 0                AULLA LUNIGIANA               2       REG  1662349440
# 1                AULLA LUNIGIANA              -3       REG  1662352320
# ...

# %%
for index,row in tqdm(delays.iterrows()):
    if(pd.notnull(delays['cn'][index])):
        old_value = row['codice'].split("*")
        delays_exp.loc[(delays_exp.codice == old_value[0]) & 
                       (delays_exp.data_giorno == row['date']), 'codice'] = row['codice']
# Out:
# 71797it [02:17, 520.43it/s]

# %%
row['codice']
# Out:
# '18610'

# %%
value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 value
#
# NameError: name 'value' is not defined

# %%
new_codice

# %%
delays_exp["codice"] = delays_exp["codice"].astype(str)

z = delays_exp.loc[(delays_exp['codice'].str.len() >= 6)]
z.head()

# %% [markdown]
# delays_expanded.to_csv('../processed_files/delays_preprocessing_expanded.csv')
