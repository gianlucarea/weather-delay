# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# # Load Datasets

# %%
df_classification = pd.read_csv("../processed_files/df_for_ml.csv", index_col=[0])

# %%
df_classification = df_classification.drop(['arrival_delay'], axis=1)

# %% [markdown]
# ## Getting Ready

# %%
X_train, X_test, y_train, y_test = train_test_split(df_classification.loc[:, df_classification.columns != "isArrivalDelay"].values , df_classification["isArrivalDelay"].values , test_size=0.20, random_state=1)
print(f"X_train shape: {X_train.shape} | X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape} | y_test shape: {y_test.shape}")
# Out:
# X_train shape: (200346, 29) | X_test shape: (50087, 29)
# y_train shape: (200346,) | y_test shape: (50087,)

# %% [markdown]
# # Classification Using Undersampling

# %%
rus = RandomUnderSampler(random_state=42)
X_train, y_train = rus.fit_resample(X_train, y_train)

# %%
X_train.shape
# Out:
# (88616, 29)

# %%
y_train.shape
# Out:
# (88616,)

# %%
# Plotting the percentage of observations that fall under each class
ax = pd.DataFrame(y_train).value_counts().sort_values().plot(kind="barh", color=["r", "g"])
ax.margins(0.10, None)
ax.set_axisbelow(True)
ax.grid()
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
plt.title("isArrivalDelay", fontsize=20)
plt.xlabel("Count", fontsize=14)
plt.ylabel("Class", fontsize=14)
plt.show()
print(pd.DataFrame(y_train).value_counts())
fig = ax.get_figure()
fig.savefig("../images/under_sampling_images/balance_under_sample.png")
# Out:
# 0.0    44308
# 1.0    44308
# Name: count, dtype: int64

# %% [markdown]
# ### Decision Tree Classifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
joblib.dump(model, "./models/under_sampling/DecisionTreeClassifier.joblib")
#model = joblib.load("./models/under_sampling/DecisionTreeClassifier.joblib")
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))                                                     
cf_matrix = confusion_matrix(y_test, y_pred )
sns.heatmap(cf_matrix, annot=True  , cmap='Blues', fmt=',d')
plt.ylim(0,2)
plt.xlim(2,0)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.yticks(rotation=0) 
plt.title("Decision Tree Under Sampling Classifier")
plt.savefig("../images/under_sampling_images/DecisionTreeClassifier_us.png")

# Clean Memory
del model
del y_pred
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.88      0.77     11050
#          1.0       0.96      0.89      0.92     39037
#
#     accuracy                           0.88     50087
#    macro avg       0.82      0.88      0.85     50087
# weighted avg       0.90      0.88      0.89     50087

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestClassifier(n_jobs=-1)

model.fit(X_train, y_train)
joblib.dump(model, "./models/under_sampling/RandomForestClassifier.joblib")
#model = joblib.load("./models/under_sampling/RandomForestClassifier.joblib")
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))

cf_matrix = confusion_matrix(y_test, y_pred )
sns.heatmap(cf_matrix, annot=True  , cmap='Blues', fmt=',d')
plt.ylim(0,2)
plt.xlim(2,0)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.yticks(rotation=0) 
plt.title("Random Forest Under Sampling Classifier")
plt.savefig("../images/under_sampling_images/RandomForestClassifier_us.png")

# Clean Memory
del model
del y_pred
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.94      0.80     11050
#          1.0       0.98      0.89      0.93     39037
#
#     accuracy                           0.90     50087
#    macro avg       0.84      0.91      0.87     50087
# weighted avg       0.92      0.90      0.90     50087

# %% [markdown]
# ### ExtraTreesClassifier

# %%
model = ExtraTreesClassifier(n_jobs=-1)
model.fit(X_train, y_train)
joblib.dump(model, "./models/under_sampling/ExtraTreesClassifier.joblib")
# model = joblib.load("./models/under_sampling/ExtraTreesClassifier.joblib")
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))

cf_matrix = confusion_matrix(y_test, y_pred )
sns.heatmap(cf_matrix, annot=True  , cmap='Blues', fmt=',d')
plt.ylim(0,2)
plt.xlim(2,0)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.yticks(rotation=0) 
plt.title("Extra Tree Under Sampling Classifier")
plt.savefig("../images/under_sampling_images/ExtraTreesClassifier_us.png")

# Clean Memory
del model
del y_pred
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.92      0.78     11050
#          1.0       0.97      0.88      0.92     39037
#
#     accuracy                           0.89     50087
#    macro avg       0.83      0.90      0.85     50087
# weighted avg       0.91      0.89      0.89     50087

# %% [markdown]
# ### Gradient Boosting

# %%
model = GradientBoostingClassifier()
model.fit(X_train, y_train)
joblib.dump(model, "./models/under_sampling/GradientBoostingClassifier.joblib")
#model = joblib.load("./models/under_sampling/GradientBoostingClassifier.joblib")
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))

cf_matrix = confusion_matrix(y_test, y_pred )
sns.heatmap(cf_matrix, annot=True  , cmap='Blues', fmt=',d')
plt.ylim(0,2)
plt.xlim(2,0)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.yticks(rotation=0) 
plt.title("Gradient Boosting Under Sampling Classifier")
plt.savefig("../images/under_sampling_images/GradientBoostingClassifier_us.png")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.92      0.77     11050
#          1.0       0.97      0.87      0.92     39037
#
#     accuracy                           0.88     50087
#    macro avg       0.82      0.89      0.84     50087
# weighted avg       0.90      0.88      0.88     50087

# %% [markdown]
# ### Bagging Classifier

# %%
model = BaggingClassifier()
model.fit(X_train, y_train)
joblib.dump(model, "./models/under_sampling/BaggingClassifier.joblib")
#model = joblib.load("./models/under_sampling/BaggingClassifier.joblib")
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))

cf_matrix = confusion_matrix(y_test, y_pred )
sns.heatmap(cf_matrix, annot=True  , cmap='Blues', fmt=',d')
plt.ylim(0,2)
plt.xlim(2,0)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.yticks(rotation=0) 
plt.title("Bagging Under Sampling Classifier")
plt.savefig("../images/under_sampling_images/BaggingClassifier.png")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.94      0.79     11050
#          1.0       0.98      0.88      0.93     39037
#
#     accuracy                           0.89     50087
#    macro avg       0.83      0.91      0.86     50087
# weighted avg       0.92      0.89      0.90     50087

# %% [markdown]
# ### AdaBoost Classifier

# %%
model = AdaBoostClassifier()
model.fit(X_train, y_train)
joblib.dump(model, "./models/under_sampling/AdaBoostClassifier.joblib")
#model = joblib.load("./models/under_sampling/AdaBoostClassifier.joblib")
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))

cf_matrix = confusion_matrix(y_test, y_pred )
sns.heatmap(cf_matrix, annot=True  , cmap='Blues', fmt=',d')
plt.ylim(0,2)
plt.xlim(2,0)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.yticks(rotation=0) 
plt.title("AdaBoost Under Sampling Classifier")
plt.savefig("../images/under_sampling_images/AdaBoostClassifier.png")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.87      0.73     11050
#          1.0       0.96      0.85      0.90     39037
#
#     accuracy                           0.86     50087
#    macro avg       0.79      0.86      0.82     50087
# weighted avg       0.89      0.86      0.86     50087

# %% [markdown]
# # Statistic on Classifiers

# %%
stats = pd.DataFrame(columns=["classifiers", "fpr", "tpr", "auc"])


classifiers = ["DecisionTreeClassifier", "ExtraTreesClassifier", "GradientBoostingClassifier",
               "RandomForestClassifier","BaggingClassifier","AdaBoostClassifier"]
for classifier in classifiers:
    # Load the trained classifiers
    load_path = "./models/under_sampling/"+classifier+".joblib"
    model = joblib.load(load_path)
    y_pred = model.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test,  y_pred)
    auc = roc_auc_score(y_test, y_pred)
    # Record the results
    row = {"classifiers": classifier,"fpr": fpr,"tpr": tpr,"auc": auc}
    stats = pd.concat([stats, pd.DataFrame([row])], ignore_index=True)
    
    del model
    del y_pred

# Set name of the classifiers as index labels
stats.set_index("classifiers", inplace=True)

# %%
fig = plt.figure(figsize=(8,6), dpi=80)
for classifier in stats.index:
    plt.plot(stats.loc[classifier]["fpr"], 
             stats.loc[classifier]["tpr"], 
             label="{}, AUC={:.3f}".format(classifier, stats.loc[classifier]["auc"]))
    
plt.plot([0,1], [0,1], color='red', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("False Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title("ROC AUC Analysis", fontweight="bold", fontsize=15)
plt.legend(prop={"size":13}, loc="lower right")

plt.show()
fig.savefig("../images/under_sampling_images/classifiers_statistics_us.png")

# %%
stats
# Out:
#                                                          fpr  \
# classifiers
# DecisionTreeClassifier        [0.0, 0.1248868778280543, 1.0]
# ExtraTreesClassifier         [0.0, 0.08443438914027149, 1.0]
# GradientBoostingClassifier   [0.0, 0.08361990950226245, 1.0]
# RandomForestClassifier      [0.0, 0.059547511312217194, 1.0]
# BaggingClassifier           [0.0, 0.058642533936651586, 1.0]
# AdaBoostClassifier           [0.0, 0.13140271493212669, 1.0]
#
#                                                        tpr       auc
# classifiers
# DecisionTreeClassifier      [0.0, 0.8857750339421574, 1.0]  0.880444
# ExtraTreesClassifier        [0.0, 0.8773727489305019, 1.0]  0.896469
# GradientBoostingClassifier  [0.0, 0.8665881087173707, 1.0]  0.891484
# RandomForestClassifier        [0.0, 0.88700463662679, 1.0]  0.913729
# BaggingClassifier           [0.0, 0.8768604144785717, 1.0]  0.909109
# AdaBoostClassifier           [0.0, 0.853421113302764, 1.0]  0.861009

# %%
stats.to_csv("../processed_files/under_sampling_auc.csv")
